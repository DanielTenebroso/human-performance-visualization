# %% [markdown]
# # 🧠 Human Performance Data Visualization
#
# This notebook presents three visualizations designed to analyze and communicate five key dimensions of human performance:
#
# - **📊 Radar Chart** – compares multiple performance metrics in a single view.
# - **📈 Line Chart** – shows the weekly progression of cognitive clarity over time.
# - **🧠 Concept Map** – represents how the core dimensions of performance relate to a central concept.
#
# The metrics included are:
# - Physical Endurance
# - Cognitive Clarity
# - Emotional Balance
# - Detox Level
# - Longevity Potential
#
# The goal is to showcase data visualization skills using Python, with libraries such as `matplotlib`, `pandas`, and `graphviz`, applied to topics of personal optimization and human development.

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = [
    "Physical Endurance",
    "Cognitive Clarity",
    "Emotional Balance",
    "Detox Level",
    "Longevity Potential"
]
values = [7.5, 8.2, 6.8, 7.0, 9.0]
values += values[:1]
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.plot(angles, values, color='crimson', linewidth=2)
ax.fill(angles, values, color='lightcoral', alpha=0.5)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.set_yticks([2, 4, 6, 8, 10])
ax.set_ylim(0, 10)
plt.title("📊 Human Performance Radar Chart")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

weeks = ["Week 1", "Week 2", "Week 3", "Week 4"]
cognitive_scores = [6.5, 7.0, 8.0, 8.2]

df = pd.DataFrame({"Week": weeks, "Cognitive Clarity": cognitive_scores})

# Gráfico de línea
plt.figure(figsize=(8, 4))
plt.plot(df["Week"], df["Cognitive Clarity"], marker='o', color='royalblue', linewidth=2)
plt.title("📈 Cognitive Clarity Over Time", fontsize=14)
plt.xlabel("Week")
plt.ylabel("Score")
plt.grid(True)
plt.ylim(0, 10)
plt.show()

# %%
df.plot(kind="bar", x="Week", y="Cognitive Clarity", color='skyblue', legend=False)
plt.title("📊 Weekly Cognitive Clarity")
plt.ylim(0, 10)
plt.ylabel("Score")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install graphviz

# %%
from graphviz import Digraph

dot = Digraph()

dot.node('H', 'Human Performance')
dot.node('PE', 'Physical Endurance')
dot.node('CC', 'Cognitive Clarity')
dot.node('EB', 'Emotional Balance')
dot.node('DL', 'Detox Level')
dot.node('LP', 'Longevity Potential')

dot.edges([('H', 'PE'), ('H', 'CC'), ('H', 'EB'), ('H', 'DL'), ('H', 'LP')])
dot.render(view=True, format='png')  # Se guarda como archivo

dot
# Out:
# Error: no "view" mailcap rules found for type "image/png"
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening 'Digraph.gv.png'

# %% [markdown]
# ## ✅ Conclusion
#
# This visualization exercise provides an intuitive way to observe and evaluate key dimensions of human performance—both in a comparative snapshot and as they evolve over time.
#
# - The radar chart offers a holistic overview of strengths and areas for growth.
# - The line chart tracks the progress of a single metric (cognitive clarity), ideal for weekly or monthly monitoring.
# - The concept map helps frame these dimensions within a systems-thinking perspective.
#
# These visualizations could be integrated into coaching tools, wellness dashboards, performance tracking systems, or future-oriented self-assessment models.
#
# ---
#
# **Author:** Leandro Coronel
# **Contact:** leandro.d.coronel@gmail.com
# **Linkedin:** https://www.linkedin.com/in/leandro-daniel-coronel/
